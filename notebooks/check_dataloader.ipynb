# %%
cd ..
# Out:
# /Users/dani/Google Drive/Uni/Master/P4 2021/DD2424 - Deep Learning for Data Science/Project/ScarceClassifier

# %%
from src.d04_mixmatch.wideresnet import WideResNet
from src.d02_data.load_data import get_dataloaders_ssl
from src.d03_processing.transform_data import AddGaussianNoise
from src.d07_visualization.visualize_cifar10 import show_img
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import numpy as np
import time

# %%
 train_labeled_loader, train_unlabeled_loader, val_loader, test_loader = get_dataloaders_ssl(path='../data')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
iter_loader = iter(train_labeled_loader)

# %%
    iter_loader = iter(train_labeled_loader)
    try:
        inputs_x, targets_x = iter_loader.next()
        if inputs_x.shape[0] < batch_size:
            iter_loader = iter(train_labeled_loader)
            inputs_x, targets_x = iter_loader.next()

    except:
        iter_loader = iter(train_labeled_loader)
        inputs_x, targets_x = iter_loader.next()
# Out:
# next time: 0.0017940998077392578
# tensor(0.0328)
# torch.Size([64, 3, 32, 32])
# next time: 0.0014739036560058594
# tensor(-2.4291)
# torch.Size([64, 3, 32, 32])
# next time: 0.0009310245513916016
# tensor(2.5141)
# torch.Size([58, 3, 32, 32])
# loader time: 0.030025959014892578
# tensor(2.5141)----
# torch.Size([64, 3, 32, 32])
# next time: 0.002950906753540039
# tensor(1.1959)
# torch.Size([64, 3, 32, 32])
# next time: 0.0034360885620117188
# tensor(1.1959)
# torch.Size([64, 3, 32, 32])
# next time: 0.0031189918518066406
# tensor(0.1879)
# torch.Size([58, 3, 32, 32])
# loader time: 0.018764019012451172
# tensor(1.1959)----
# torch.Size([64, 3, 32, 32])
# next time: 0.0032100677490234375
# tensor(1.9325)
# torch.Size([64, 3, 32, 32])
# next time: 0.0022077560424804688
# tensor(-1.4211)
# torch.Size([64, 3, 32, 32])
# next time: 0.002783060073852539
# tensor(-2.0026)
# torch.Size([58, 3, 32, 32])
# loader time: 0.02169489860534668
# tensor(2.4753)----
# torch.Size([64, 3, 32, 32])
# ...

# %%
for _ in range(10):
    iter_loader = iter(train_labeled_loader)
    inputs_x, targets_x = iter_loader.next()
    print(inputs_x[0].shape)
    show_img(inputs_x[0])
# Out:
# torch.Size([3, 32, 32])
# torch.Size([3, 32, 32])
# torch.Size([3, 32, 32])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([3, 32, 32])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([3, 32, 32])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([3, 32, 32])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([3, 32, 32])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([3, 32, 32])
# torch.Size([3, 32, 32])
# torch.Size([3, 32, 32])
